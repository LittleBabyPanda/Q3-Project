# %%
from matplotlib import pyplot as plt

# %%
from jyquickhelper import add_notebook_menu
add_notebook_menu()
# Out:
# <div id="my_id_menu_nb">run previous cell, wait for 2 seconds</div>
# <script>
# function repeat_indent_string(n){
#     var a = "" ;
#     for ( ; n > 0 ; --n)
#         a += "    ";
#     return a;
# }
# // look up into all sections and builds an automated menu //
# var update_menu_string = function(begin, lfirst, llast, sformat, send, keep_item, begin_format, end_format) {
#     var anchors = document.getElementsByClassName("section");
#     if (anchors.length == 0) {
#         anchors = document.getElementsByClassName("text_cell_render rendered_html");
#     }
#     var i,t;
#     var text_menu = begin;
#     var text_memo = "<pre>\nlength:" + anchors.length + "\n";
#     var ind = "";
#     var memo_level = 1;
#     var href;
#     var tags = [];
#     var main_item = 0;
#     var format_open = 0;
#     for (i = 0; i <= llast; i++)
#         tags.push("h" + i);
#
#     for (i = 0; i < anchors.length; i++) {
#         text_memo += "**" + anchors[i].id + "--\n";
#
# ...

# %%
# %matplotlib inline

# %%
''' Méthode longue '''
fig1 = plt.figure(figsize=(5,5)) # Pour créer la figure
ax = plt.subplot(1,1,1) # Pour créer le graphique (l'axe), à la position (1,1), indicé 1

# %%
fig1.add_subplot(2,1,2) #Ajouté à la position (2,1), indicé 2
fig2.add_axes()

# %%
import numpy as np
X = np.linspace(0,10,1000)
Y = np.sin(X)
axes[0].plot(X,Y)
fig2

# %%
''' Mettre un titre '''

plt.title('Titre') # Pour le titre de la figure entière. Attribue le titre à la dernière figure active.
ax.set_title('Titre d\'axe') # Pour les graphiques.

''' Rajouter une légende '''

plt.legend() # loc= permet de mettre la légendre à différents endroits. La légende va indiquer tous les labels.
ax.legend() # Pour ne montrer la légende que sur un axe.

''' Renommer les axes '''

ax.set(xlabel='Nom des abscisses',ylabel='Nom des ordonnées')

''' Ajuster la longueur des axes '''

ax.axis([0,1,0,1]) # Les abscisses varient entre 0 et 1, idem pour les ordonnées.
ax.set_xlim([0,1]) # Solution alternative
ax.set_ylim([0,1])

''' Modifier la graduation (les 'ticks') '''



''' Faire en sorte que les graphes partagent leur graduations '''
